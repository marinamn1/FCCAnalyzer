# %%
import uproot
import matplotlib.pyplot as plt
import numpy as np
import hist
from hist import Hist
import mplhep as hep
import math

genkt = uproot.open("/home/submit/marinamn/fccee/FCCAnalyzer/tmp/output_z_xsec_qq_kt.root")

# %%
ep = genkt['wzp6_ee_qq_ecm91p2/ep;1'].to_hist()
epn = genkt["kkmc_ee_uu_ecm91p2/ep"].to_hist()+ genkt["kkmc_ee_dd_ecm91p2/ep"].to_hist()+genkt["kkmc_ee_cc_ecm91p2/ep"].to_hist() +genkt["kkmc_ee_ss_ecm91p2/ep"].to_hist() + genkt["kkmc_ee_bb_ecm91p2/ep"].to_hist()
tau_ep = genkt['wzp6_ee_tautau_ecm91p2/ep;1'].to_hist()
gaga_ep = genkt['wzp6_gaga_qq_5_ecm91p2/ep;1'].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot([gaga_ep,tau_ep,epn], label = [r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$ hadrons", 
                                            r"$e^{+} e^{-} \rightarrow \tau^{+} \tau^{-}$",
                                               r"$e^{+} e^{-} \rightarrow q \bar{q}$"], 
             stack = True, histtype = "fill",color = ["yellow", "limegreen", "paleturquoise"])
plt.yscale("log")
plt.xlim(0,1)
plt.ylim(1,3.35e5)
plt.xlabel(r"$E_{\parallel}$/$E_{vis}$")
plt.legend(loc = "upper right")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_ep.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
et = genkt['wzp6_ee_qq_ecm91p2/et;1'].to_hist()
etn = genkt["kkmc_ee_uu_ecm91p2/et"].to_hist()+ genkt["kkmc_ee_dd_ecm91p2/et"].to_hist()+genkt["kkmc_ee_cc_ecm91p2/et"].to_hist() +genkt["kkmc_ee_ss_ecm91p2/et"].to_hist() + genkt["kkmc_ee_bb_ecm91p2/et"].to_hist()
mu_et = genkt['wzp6_ee_mumu_ecm91p2/et;1'].to_hist()
tau_et = genkt['wzp6_ee_tautau_ecm91p2/et;1'].to_hist()
gaga_et = genkt['wzp6_gaga_qq_5_ecm91p2/et;1'].to_hist()
e_et = genkt["p8_ee_Zee_ecm91/et"].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot([e_et,gaga_et,tau_et,etn], label = [r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$",r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$ hadrons", 
                                            r"$e^{+} e^{-} \rightarrow \tau^{+} \tau^{-}$",
                                               r"$e^{+} e^{-} \rightarrow q \bar{q}$"], 
             stack = True, histtype = "fill",color = ["pink","yellow", "limegreen", "paleturquoise"])
plt.yscale("log")
plt.xlim(0,1)
plt.ylim(1,4.5e5)
plt.xlabel(r"$E_{\perp}$/$E_{vis}$")
plt.legend(loc = "upper right")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_et.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
no = genkt['wzp6_ee_qq_ecm91p2/RP_no;1'].to_hist()
non = genkt["kkmc_ee_uu_ecm91p2/RP_no"].to_hist()+ genkt["kkmc_ee_dd_ecm91p2/RP_no"].to_hist()+genkt["kkmc_ee_cc_ecm91p2/RP_no"].to_hist() +genkt["kkmc_ee_ss_ecm91p2/RP_no"].to_hist() + genkt["kkmc_ee_bb_ecm91p2/RP_no"].to_hist()
mu_no = genkt['wzp6_ee_mumu_ecm91p2/RP_no;1'].to_hist()
e_no = genkt["p8_ee_Zee_ecm91/RP_no"].to_hist()
tau_no = genkt['wzp6_ee_tautau_ecm91p2/RP_no;1'].to_hist()
gaga_no = genkt['wzp6_gaga_qq_5_ecm91p2/RP_no;1'].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot([mu_no,e_no, gaga_no, tau_no, non], label = [r"$e^{+} e^{-} \rightarrow \mu^{+} \mu^{-}$",r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$",
                      r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$ hadrons", r"$e^{+} e^{-} \rightarrow \tau^{+} \tau^{-}$",
                                               r"$e^{+} e^{-} \rightarrow q \bar{q}$"], 
             stack = True, histtype = "fill", color = ["red","pink","yellow", "limegreen", "paleturquoise"])
plt.yscale("log")
plt.xlim(0,120)
plt.ylim(1,7e4)
plt.xlabel(r"Number of Particles ($|cos(\theta)| > 0.74$)")
plt.legend(loc = "upper right")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_cos_bigger_0_74.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
no = genkt['wzp6_ee_qq_ecm91p2/RP_no;1'].to_hist()
non = genkt["kkmc_ee_uu_ecm91p2/RP_no"].to_hist()+ genkt["kkmc_ee_dd_ecm91p2/RP_no"].to_hist()+genkt["kkmc_ee_cc_ecm91p2/RP_no"].to_hist() +genkt["kkmc_ee_ss_ecm91p2/RP_no"].to_hist() + genkt["kkmc_ee_bb_ecm91p2/RP_no"].to_hist()
mu_no = genkt['wzp6_ee_mumu_ecm91p2/RP_no;1'].to_hist()
e_no = genkt["p8_ee_Zee_ecm91/RP_no"].to_hist()
tau_no = genkt['wzp6_ee_tautau_ecm91p2/RP_no;1'].to_hist()
gaga_no = genkt['wzp6_gaga_qq_5_ecm91p2/RP_no;1'].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot([mu_no,e_no, tau_no, non], label = [r"$e^{+} e^{-} \rightarrow \mu^{+} \mu^{-}$",r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$",
                    r"$e^{+} e^{-} \rightarrow \tau^{+} \tau^{-}$",
                                               r"$e^{+} e^{-} \rightarrow q \bar{q}$"], 
             stack = True, histtype = "fill", color = ["red","pink", "limegreen", "paleturquoise"])
plt.yscale("log")
plt.xlim(0,120)
plt.ylim(1,7e4)
plt.xlabel(r"Number of Particles ($|cos(\theta)| \leqslant 0.74$)")
plt.legend(loc = "upper right")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_cos_smaller_0_74.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
e = genkt['wzp6_ee_qq_ecm91p2/norm_energy;1'].to_hist()
en = genkt["kkmc_ee_uu_ecm91p2/norm_energy"].to_hist()+ genkt["kkmc_ee_dd_ecm91p2/norm_energy"].to_hist()+genkt["kkmc_ee_cc_ecm91p2/norm_energy"].to_hist() +genkt["kkmc_ee_ss_ecm91p2/norm_energy"].to_hist() + genkt["kkmc_ee_bb_ecm91p2/norm_energy"].to_hist()
tau_e = genkt['wzp6_ee_tautau_ecm91p2/norm_energy;1'].to_hist()
gaga_e = genkt['wzp6_gaga_qq_5_ecm91p2/norm_energy;1'].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot([gaga_e, tau_e, en], label = [r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$ hadrons",
                      r"$e^{+} e^{-} \rightarrow \tau^{+} \tau^{-}$",
                                               r"$e^{+} e^{-} \rightarrow q \bar{q}$"], 
             stack = True, histtype = "fill", color = ["yellow","limegreen", "paleturquoise"])
plt.yscale("log")
plt.xlim(0.2,2.22)
plt.ylim(1,5e6)
plt.xlabel(r"$E_{vis}/\sqrt{s}$")
plt.legend(loc = "upper right")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_norm_e.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
uu = genkt["kkmc_ee_uu_ecm91p2/norm_energy"].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot(uu, label = r"$e^{+} e^{-} \rightarrow q \bar{q}$", histtype = "fill", color = "paleturquoise")
plt.yscale("log")
plt.xlim(0.2,2.22)
plt.ylim(1,5e6)
plt.xlabel(r"$E_{vis}/\sqrt{s}$")
plt.legend(loc = "upper right")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_norm_e_uu.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
uu = genkt["kkmc_ee_uu_ecm91p2_noISR/norm_energy"].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot(uu, label = r"$e^{+} e^{-} \rightarrow q \bar{q} $ (no ISR)", histtype = "fill", color = "paleturquoise")
plt.yscale("log")
plt.xlim(0.2,1.11)
plt.ylim(1,1e6)
plt.xlabel(r"$E_{vis}/\sqrt{s}$")
plt.legend(loc = "upper right")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_norm_e_uu_noISR.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
cuts = genkt['wzp6_ee_qq_ecm91p2/cutFlow;1'].to_hist()
cutsn = genkt["kkmc_ee_uu_ecm91p2/cutFlow"].to_hist()+ genkt["kkmc_ee_dd_ecm91p2/cutFlow"].to_hist()+genkt["kkmc_ee_cc_ecm91p2/cutFlow"].to_hist() +genkt["kkmc_ee_ss_ecm91p2/cutFlow"].to_hist() + genkt["kkmc_ee_bb_ecm91p2/cutFlow"].to_hist()
mu_cuts = genkt['wzp6_ee_mumu_ecm91p2/cutFlow;1'].to_hist()
e_cuts = genkt["p8_ee_Zee_ecm91/cutFlow"].to_hist()
tau_cuts = genkt['wzp6_ee_tautau_ecm91p2/cutFlow;1'].to_hist()
gaga_cuts = genkt['wzp6_gaga_qq_5_ecm91p2/cutFlow;1'].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot([mu_cuts,e_cuts, gaga_cuts, tau_cuts, cutsn], label = [r"$e^{+} e^{-} \rightarrow \mu^{+} \mu^{-}$",r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$",
                                                                    r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$ hadrons",
                                            r"$e^{+} e^{-} \rightarrow \tau^{+} \tau^{-}$",
                                               r"$e^{+} e^{-} \rightarrow q \bar{q}$"], 
             stack = True, histtype = "fill", color = ["red","pink", "yellow", "limegreen", "paleturquoise"])
plt.yscale("log")
#plt.xlim(0,120)
#plt.ylim(1,7e4)
plt.xlabel("Cuts")
plt.legend(loc = "lower left", fontsize = "10")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_cutflow.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
x, y = cutsn.to_numpy()
mux, muy = mu_cuts.to_numpy()
ex, ey = e_cuts.to_numpy()
taux, tauy = tau_cuts.to_numpy()
gagax, gagay = gaga_cuts.to_numpy()

print(x)
# Out:
# [1380249.33814212 1380249.33814212 1376953.66078185 1373750.22489263
#  1302901.98800241]

# %%
print(mux)
print(ex)
print(taux)
print(gagax)
# Out:
# [75779.6        75779.6        74291.56091804 74146.61768551
#      0.        ]
# [6.55601156e+04 6.55601156e+04 6.49204980e+04 6.48312313e+04
#  9.11285607e-01]
# [7.62280000e+04 7.62280000e+04 7.16225659e+04 6.47607919e+04
#  7.51093879e+01]
# [509712.4224     509712.4224     368067.80019874 365890.81844267
#    6758.1495805 ]

# %%
tn = genkt['wzp6_ee_qq_ecm91p2/thrust;1'].to_hist()
thrust = genkt["kkmc_ee_uu_ecm91p2/thrust"].to_hist()+ genkt["kkmc_ee_dd_ecm91p2/thrust"].to_hist()+genkt["kkmc_ee_cc_ecm91p2/thrust"].to_hist() +genkt["kkmc_ee_ss_ecm91p2/thrust"].to_hist() + genkt["kkmc_ee_bb_ecm91p2/thrust"].to_hist()
mu_t = genkt['wzp6_ee_mumu_ecm91p2/thrust;1'].to_hist()
e_t = genkt["p8_ee_Zee_ecm91/thrust"].to_hist()
tau_t = genkt['wzp6_ee_tautau_ecm91p2/thrust;1'].to_hist()
gaga_t = genkt['wzp6_gaga_qq_5_ecm91p2/thrust;1'].to_hist()

plt.figure(figsize=(5.5,8.2))
# hep.histplot([mu_t,e_t, gaga_t, tau_t, t], label = [r"$e^{+} e^{-} \rightarrow \mu^{+} \mu^{-}$",r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$",
#                       r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$ hadrons", r"$e^{+} e^{-} \rightarrow \tau^{+} \tau^{-}$",
#                                                r"$e^{+} e^{-} \rightarrow q \bar{q}$"], 
#              stack = True, histtype = "fill", color = ["red","pink","yellow", "limegreen", "paleturquoise"])
hep.histplot(thrust,label = r"$e^{+} e^{-} \rightarrow q \bar{q}$", histtype = "fill", color = "paleturquoise")
plt.yscale("log")
plt.xlim(0.6,1.05)
plt.ylim(1,1e6)
plt.xlabel("Thrust Magnitude")
plt.legend(loc = "upper left")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_thrust.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')

# %%
tn = genkt['wzp6_ee_qq_ecm91p2/cos_thetat;1'].to_hist()
t = genkt["kkmc_ee_uu_ecm91p2/cos_thetat"].to_hist()+ genkt["kkmc_ee_dd_ecm91p2/cos_thetat"].to_hist()+genkt["kkmc_ee_cc_ecm91p2/cos_thetat"].to_hist() +genkt["kkmc_ee_ss_ecm91p2/cos_thetat"].to_hist() + genkt["kkmc_ee_bb_ecm91p2/cos_thetat"].to_hist()
mu_t = genkt['wzp6_ee_mumu_ecm91p2/cos_thetat;1'].to_hist()
e_t = genkt["p8_ee_Zee_ecm91/cos_thetat"].to_hist()
tau_t = genkt['wzp6_ee_tautau_ecm91p2/cos_thetat;1'].to_hist()
gaga_t = genkt['wzp6_gaga_qq_5_ecm91p2/cos_thetat;1'].to_hist()

plt.figure(figsize=(5.5,8.2))
hep.histplot([mu_t,e_t, gaga_t, tau_t, t], label = [r"$e^{+} e^{-} \rightarrow \mu^{+} \mu^{-}$",r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$",
                      r"$e^{+} e^{-} \rightarrow e^{+} e^{-}$ hadrons", r"$e^{+} e^{-} \rightarrow \tau^{+} \tau^{-}$",
                                               r"$e^{+} e^{-} \rightarrow q \bar{q}$"], 
             stack = True, histtype = "fill", color = ["red","pink","yellow", "limegreen", "paleturquoise"])
plt.yscale("log")
plt.xlim(-0.01,1.01)
plt.xlabel(r"|cos $\theta_{t}$|")
plt.legend(loc = "upper center")
plt.ylabel("Events")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 44.84 pb$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
#plt.savefig("l3_cos_thetat.png")
# Out:
# Text(0.0, 1.0, 'FCC-ee simulation')
