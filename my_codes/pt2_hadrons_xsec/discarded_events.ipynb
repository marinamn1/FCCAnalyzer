# %%
import uproot
import matplotlib.pyplot as plt
import numpy as np
import hist
from hist import Hist
import mplhep as hep
import math

f = uproot.open("/home/submit/marinamn/fccee/FCCAnalyzer/tmp/output_hadron_xsec.root")

def qq(key):
    #f = uproot.open("/home/submit/marinamn/fccee/FCCAnalyzer/tmp/output_hadron_xsec.root")
    qq = f[f"kkmc_ee_uu_ecm91p2/{key}"].to_hist()+ f[f"kkmc_ee_dd_ecm91p2/{key}"].to_hist()+f[f"kkmc_ee_cc_ecm91p2/{key}"].to_hist() +f[f"kkmc_ee_ss_ecm91p2/{key}"].to_hist() + f[f"kkmc_ee_bb_ecm91p2/{key}"].to_hist()
    return qq

# %%
discard2_no = qq("discard2RP_no_vis")
hep.histplot(discard2_no, label = r"$e^{+} e^{-} \rightarrow q \bar{q}$", color = "paleturquoise", histtype = "fill")
plt.xlim(0,30)
plt.xlabel(r"Reconstructed Particles")
plt.legend(loc = "lower center")
plt.yscale("log")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 75 ab$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
plt.text(29,7.5e8,"Events with Scalar Energy < 22.6 GeV", verticalalignment='top', horizontalalignment='right')
plt.ylabel("Events")
#plt.savefig(f"images/discard2_no.png")
# Out:
# Text(0, 0.5, 'Events')

# %%
discard1_e = qq("discard1sum_energy")
hep.histplot(discard1_e, label = r"$e^{+} e^{-} \rightarrow q \bar{q}$", color = "paleturquoise", histtype = "fill")
plt.xlim(0,100)
plt.xlabel(r"Scalar Energy [GeV]")
plt.legend(loc = "lower center")
plt.yscale("log")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 75 ab$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
plt.text(80,6.5e8,"Events with Number of Reconstructed Particles < 10", verticalalignment='top', horizontalalignment='right')
plt.ylabel("Events")
#plt.savefig(f"images/discard1_e.png")
# Out:
# Text(0, 0.5, 'Events')

# %%
discard_no = qq("discard1RP_no_vis") + qq("discard2RP_no_vis")
hep.histplot(discard_no, label = r"$e^{+} e^{-} \rightarrow q \bar{q}$", color = "paleturquoise", histtype = "fill")
plt.xlim(0,30)
plt.xlabel(r"Reconstructed Particles")
plt.legend(loc = "lower center")
plt.yscale("log")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 75 ab$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
plt.text(29,7.5e9,"All discarded events", verticalalignment='top', horizontalalignment='right')
plt.ylabel("Events")
#plt.savefig(f"images/discard_no.png")
# Out:
# Text(0, 0.5, 'Events')

# %%
discard_e = qq("discard1sum_energy") + qq("discard2sum_energy")
hep.histplot(discard_e, label = r"$e^{+} e^{-} \rightarrow q \bar{q}$", color = "paleturquoise", histtype = "fill")
plt.xlim(0,100)
plt.xlabel(r"Scalar Energy [GeV]")
plt.legend(loc = "lower center")
plt.yscale("log")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 75 ab$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
plt.text(80,6.5e8,"All discarded events", verticalalignment='top', horizontalalignment='right')
plt.ylabel("Events")
#plt.savefig(f"images/discard_e.png")
# Out:
# Text(0, 0.5, 'Events')

# %%
discard_theta = qq("discard1RP_theta") + qq("discard2RP_theta")
hep.histplot(discard_theta, label = r"$e^{+} e^{-} \rightarrow q \bar{q}$", color = "paleturquoise", histtype = "fill")
plt.xlim(0,3.15)
plt.xlabel(r"$ \theta $ [radians]")
plt.legend(loc = "lower center")
plt.yscale("log")
plt.title(r"$\sqrt{s} = 91.2 $ GeV, 75 ab$^{-1}$", loc = "right")
plt.title("FCC-ee simulation", loc = "left", weight = "bold")
plt.text(1.5,6.5e9,"All discarded events", verticalalignment='top', horizontalalignment='right')
plt.ylabel("Events")
#plt.savefig(f"images/discard_theta.png")
# Out:
# Text(0, 0.5, 'Events')
